# %%
from rdflib import URIRef, BNode, Literal, Graph, plugin, Namespace
from rdflib.serializer import Serializer 
from rdflib.namespace import FOAF, DC, RDF, RDFS, OWL, SKOS, XSD, NamespaceManager
import csv

# %%
kgcBase = Graph()
kgcBase.parse('./base.ttl', format='ttl')
# Out:
# <Graph identifier=N56add080bc7949c980f0a82bc4dd2d5a (<class 'rdflib.graph.Graph'>)>

# %%
nmGraph = NamespaceManager(kgcBase)

kgc = Namespace("http://www.knowledgegraph.tech/")
nmGraph.bind("kgc", kgc)
kgcr = Namespace("http://www.knowledgegraph.tech/iri/")
nmGraph.bind("kgcr", kgcr)
schema = Namespace("http://schema.org/")
nmGraph.bind("schema", schema)
#wd = Namespace("http://www.wikidata.org/entity/")
wd = Namespace("http://www.wikidata.org/wiki/")
nmGraph.bind("wd", wd)
owl = Namespace("http://www.w3.org/2002/07/owl#")
nmGraph.bind("owl", owl)
skos = Namespace("http://www.w3.org/2004/02/skos/core#")
nmGraph.bind("skos", skos)
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
nmGraph.bind("rdf", rdf)
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")
nmGraph.bind("rdfs", rdfs)
xml = Namespace("http://www.w3.org/XML/1998/namespace")
nmGraph.bind("xml", xml) 
xsd = Namespace("http://www.w3.org/2001/XMLSchema#")
nmGraph.bind("xsd", xsd)

# %% [markdown]
# ## Initializations

# %%
# Initializations
kgcGraph2021=kgcBase


# Previous Data
kgcGraph2020 = Graph()
kgcGraph2020.parse('./kgc2020-1.ttl', format='ttl')

res = kgcGraph2020.query('''select distinct ?r ?name where 
{ 
{{?r schema:name ?name} Union {?r schema:archivedAt ?name} Union {?r schema:embedUrl ?name}} 
filter(regex(str(?r),"http://www.knowledgegraph.tech/iri/"))
}
''') 

for row in res:
    labelDict[str(row[1])] = row[0]
    print(str(row[1]))
    print(row[0])


ids = [int(str(r[0])[-5:]) for r in res]
ids.sort()
lastId = ids[-1]+1
print("Last id is ", lastId)
    
    
# Check if same!
res = kgcGraph2020.query('''select ?s where {?s ?p ?o. filter(regex(str(?s),"http://www.knowledgegraph.tech/iri/"))}''' )
ids = [int(str(r[0])[-5:]) for r in res]
ids.sort()
lastId2 = ids[-1]+1
print("Last id 2 is ", lastId2)
# Out:
# Fairfax County
# http://www.knowledgegraph.tech/iri/000008
# Austin
# http://www.knowledgegraph.tech/iri/000023
# Ithaca
# http://www.knowledgegraph.tech/iri/000047
# San Mateo
# http://www.knowledgegraph.tech/iri/000068
# Arlington County
# http://www.knowledgegraph.tech/iri/000077
# Seattle
# http://www.knowledgegraph.tech/iri/000096
# Sebastopol
# http://www.knowledgegraph.tech/iri/000106
# Stanford
# http://www.knowledgegraph.tech/iri/000112
# Ghent
# http://www.knowledgegraph.tech/iri/000127
# Ulm
# http://www.knowledgegraph.tech/iri/000139
# Cambridge
# http://www.knowledgegraph.tech/iri/000149
# Sunnyvale
# http://www.knowledgegraph.tech/iri/000159
# Sofia
# http://www.knowledgegraph.tech/iri/000166
# Dublin
# http://www.knowledgegraph.tech/iri/000209
# Irish Free State
# http://www.knowledgegraph.tech/iri/000216
# Charlotte
# http://www.knowledgegraph.tech/iri/000237
# Thirteen Colonies
# http://www.knowledgegraph.tech/iri/000242
# Great Britain
# http://www.knowledgegraph.tech/iri/000246
# Redmond
# http://www.knowledgegraph.tech/iri/000251
# Validating Data Categories using Knowledge Graphs
# http://www.knowledgegraph.tech/iri/000266
# A Data Catalog should be your organization's first Knowledge Graph
# http://www.knowledgegraph.tech/iri/000275
# Enterprise Knowledge Graph and Machine Learning Integration with live data
# http://www.knowledgegraph.tech/iri/000278
# Better Informing Our Readers through the Dow Jones Knowledge Graph
# http://www.knowledgegraph.tech/iri/000284
# Inventory Management Knowledge Graph
# http://www.knowledgegraph.tech/iri/000288
# Integrating data from knowledge graphs to enhance library discovery
# http://www.knowledgegraph.tech/iri/000292
# The Knowledge Graph that Listens
# http://www.knowledgegraph.tech/iri/000302
# From Semantic Networks to Knowledge Graphs
# http://www.knowledgegraph.tech/iri/000305
# Insufficient Facts Always Invite Danger: Combat Them with a Logical Model
# http://www.knowledgegraph.tech/iri/000307
# A knowledge graph of controversial claims and its applications
# http://www.knowledgegraph.tech/iri/000311
# Automated Knowledge Base creation in a large financial services organization
# http://www.knowledgegraph.tech/iri/000314
# Are Knowledge Graphs a good thing? What does it take to build one?
# http://www.knowledgegraph.tech/iri/000316
# Rich Context: a knowledge graph for linking datasets with research outcomes
# http://www.knowledgegraph.tech/iri/000320
# Use of OWL and Semantic Web Technologies at Pinterest
# http://www.knowledgegraph.tech/iri/000327
# Modeling Real Estate Ecosystem with Cherre's Knowledge Graph
# http://www.knowledgegraph.tech/iri/000329
# Personal knowledge graphs on the Web
# http://www.knowledgegraph.tech/iri/000331
# Visual Analytics of Large Knowledge Graphs
# http://www.knowledgegraph.tech/iri/000333
# Middle-Out FAIR Data Integration with Knowledge Graphs
# http://www.knowledgegraph.tech/iri/000338
# Machine learning in Yahoo Knowledge Graph
# http://www.knowledgegraph.tech/iri/000341
# Semantic Objects Please Application Developers with GraphQL and Facilitate Quality Knowledge Graphs
# http://www.knowledgegraph.tech/iri/000344
# Towards building a CRM system using a Knowledge Graph of Communication Data
# http://www.knowledgegraph.tech/iri/000349
# How Knowledge Graphs Will Help Law Firms Win Business and Serve Clients Better
# http://www.knowledgegraph.tech/iri/000352
# Using FIBO: A Use-Case Driven Cooks Tour
# http://www.knowledgegraph.tech/iri/000355
# Using Graph Analytics in Enterprise Applications
# http://www.knowledgegraph.tech/iri/000361
# A Meta-graph Solution for Recommender Systems
# http://www.knowledgegraph.tech/iri/000363
# Knowledge Graph Maintenance
# http://www.knowledgegraph.tech/iri/000366
# W3C Cyber Control Ontology and Knowledge Graph - a standard based cyber controls intelligence
# http://www.knowledgegraph.tech/iri/000368
# Entity Linking: The Symbiosis between Knowledge Graphs and News
# http://www.knowledgegraph.tech/iri/000370
# The Curious Case of the Semantic Data Catalog
# http://www.knowledgegraph.tech/iri/000371
# Knowledge Graph for Drug Discovery
# http://www.knowledgegraph.tech/iri/000373
# Brian Donohue
# http://www.knowledgegraph.tech/iri/000001
# Capital One:Tysons,,Fairfax County,Virginia,United States of America
# http://www.knowledgegraph.tech/iri/000006
# Tysons
# http://www.knowledgegraph.tech/iri/000007
# Capital One:McLean,,Fairfax County,Virginia,United States of America
# http://www.knowledgegraph.tech/iri/000013
# McLean
# http://www.knowledgegraph.tech/iri/000014
# Bethany Sehon
# http://www.knowledgegraph.tech/iri/000016
# Bryon Jacob
# http://www.knowledgegraph.tech/iri/000017
# data.world
# http://www.knowledgegraph.tech/iri/000018
# data.world:,Austin,Travis County,Texas,United States of America
# http://www.knowledgegraph.tech/iri/000022
# Chen Yong Cher
# http://www.knowledgegraph.tech/iri/000028
# Graphen, Inc.
# http://www.knowledgegraph.tech/iri/000029
# Graphen, Inc.:,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000031
# Dylan Roy
# http://www.knowledgegraph.tech/iri/000034
# Dow Jones & Company
# http://www.knowledgegraph.tech/iri/000035
# Dow Jones & Company:,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000037
# Gavin Mendel-Gleason
# http://www.knowledgegraph.tech/iri/000039
# TerminusDB
# http://www.knowledgegraph.tech/iri/000040
# Huda Khan
# http://www.knowledgegraph.tech/iri/000042
# Cornell University
# http://www.knowledgegraph.tech/iri/000043
# Ivy League
# http://www.knowledgegraph.tech/iri/000044
# Cornell University:,Ithaca,Tompkins County,New York,United States of America
# http://www.knowledgegraph.tech/iri/000046
# Jans Aasman
# http://www.knowledgegraph.tech/iri/000059
# Kingdom of the Netherlands
# http://www.knowledgegraph.tech/iri/000060
# University of Groningen
# http://www.knowledgegraph.tech/iri/000061
# AllegroGraph
# http://www.knowledgegraph.tech/iri/000062
# John F. Sowa
# http://www.knowledgegraph.tech/iri/000064
# Harvard University
# http://www.knowledgegraph.tech/iri/000065
# Kyndi, Inc.
# http://www.knowledgegraph.tech/iri/000066
# Kyndi, Inc.:,San Mateo,San Mateo County,California,United States of America
# http://www.knowledgegraph.tech/iri/000067
# Massachusetts Institute of Technology
# http://www.knowledgegraph.tech/iri/000071
# Free University of Brussels
# http://www.knowledgegraph.tech/iri/000072
# Harvard School of Engineering and Applied Sciences
# http://www.knowledgegraph.tech/iri/000073
# Michael Grove
# http://www.knowledgegraph.tech/iri/000074
# Stardog
# http://www.knowledgegraph.tech/iri/000075
# Stardog:,,Arlington County,Virginia,United States of America
# http://www.knowledgegraph.tech/iri/000076
# Konstantin Todorov
# http://www.knowledgegraph.tech/iri/000078
# University of Montpellier
# http://www.knowledgegraph.tech/iri/000079
# Mediterra
# http://www.knowledgegraph.tech/iri/000080
# Coimbra Group
# http://www.knowledgegraph.tech/iri/000082
# Couperin Consortium
# http://www.knowledgegraph.tech/iri/000083
# Renater
# http://www.knowledgegraph.tech/iri/000085
# Nicolas Seyot
# http://www.knowledgegraph.tech/iri/000086
# Morgan Stanley
# http://www.knowledgegraph.tech/iri/000087
# Morgan Stanley:,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000088
# Ora Lassila
# http://www.knowledgegraph.tech/iri/000089
# Finland
# http://www.knowledgegraph.tech/iri/000090
# Helsinki University of Technology
# http://www.knowledgegraph.tech/iri/000091
# Amazon Web Services
# http://www.knowledgegraph.tech/iri/000092
# Amazon Web Services:,Seattle,King County,Washington,United States of America
# http://www.knowledgegraph.tech/iri/000095
# Paco Nathan
# http://www.knowledgegraph.tech/iri/000103
# Derwen, Inc.
# http://www.knowledgegraph.tech/iri/000104
# Derwen, Inc.:,Sebastopol,Sonoma County,California,United States of America
# http://www.knowledgegraph.tech/iri/000105
# Rafael S Gonçalves
# http://www.knowledgegraph.tech/iri/000108
# University of Manchester
# http://www.knowledgegraph.tech/iri/000109
# Stanford University
# http://www.knowledgegraph.tech/iri/000110
# Stanford University:,Stanford,Santa Clara County,California,United States of America
# http://www.knowledgegraph.tech/iri/000111
# Pac-12 Conference
# http://www.knowledgegraph.tech/iri/000115
# Ron Bekkerman
# http://www.knowledgegraph.tech/iri/000116
# University of Massachusetts Amherst
# http://www.knowledgegraph.tech/iri/000117
# Cherre Inc.
# http://www.knowledgegraph.tech/iri/000118
# Cherre Inc.:,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000119
# Ruben Verborgh
# http://www.knowledgegraph.tech/iri/000121
# Ghent University Association
# http://www.knowledgegraph.tech/iri/000124
# Ghent University:,Ghent,East Flanders,Flemish Region,Belgium
# http://www.knowledgegraph.tech/iri/000126
# Confederation of Open Access Repositories
# http://www.knowledgegraph.tech/iri/000132
# International GLAM Labs Community
# http://www.knowledgegraph.tech/iri/000135
# Thorsten Liebig
# http://www.knowledgegraph.tech/iri/000136
# derivo GmbH
# http://www.knowledgegraph.tech/iri/000137
# derivo GmbH:,Ulm,Tübingen Government Region,Baden-Württemberg,Germany
# http://www.knowledgegraph.tech/iri/000138
# Tom Plasterer
# http://www.knowledgegraph.tech/iri/000145
# AstraZeneca
# http://www.knowledgegraph.tech/iri/000146
# AstraZeneca:,Cambridge,Cambridgeshire,East of England,England
# http://www.knowledgegraph.tech/iri/000148
# Topojoy Biswas
# http://www.knowledgegraph.tech/iri/000153
# Verizon Media
# http://www.knowledgegraph.tech/iri/000154
# Verizon Media:,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000156
# Verizon Media:,Sunnyvale,Santa Clara County,California,United States of America
# http://www.knowledgegraph.tech/iri/000158
# Node.js Foundation
# http://www.knowledgegraph.tech/iri/000160
# Vassil Momtchev
# http://www.knowledgegraph.tech/iri/000162
# Ontotext
# http://www.knowledgegraph.tech/iri/000163
# Ontotext:,Sofia,Sofia Capital Municipality,Sofia City Province,Bulgaria
# http://www.knowledgegraph.tech/iri/000165
# Christos Boutsidis
# http://www.knowledgegraph.tech/iri/000170
# Goldman Sachs
# http://www.knowledgegraph.tech/iri/000171
# Goldman Sachs:200 West Street, Battery Park City,  Manhattan,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000173
# 200 West Street, Battery Park City,  Manhattan
# http://www.knowledgegraph.tech/iri/000174
# David Kamien
# http://www.knowledgegraph.tech/iri/000178
# Mind-Alliance Systems
# http://www.knowledgegraph.tech/iri/000179
# Mind-Alliance Systems:Whippany,Hanover Township,Morris County,New Jersey,United States of America
# http://www.knowledgegraph.tech/iri/000180
# Whippany
# http://www.knowledgegraph.tech/iri/000181
# Elisa Kendall
# http://www.knowledgegraph.tech/iri/000186
# Thematix Partners LLC
# http://www.knowledgegraph.tech/iri/000187
# Thematix Partners LLC:,New York City,,New York,United States of America
# http://www.knowledgegraph.tech/iri/000189
# Melliyal Annamalai
# http://www.knowledgegraph.tech/iri/000192
# Oracle Corporation
# http://www.knowledgegraph.tech/iri/000193
# Oracle Corporation:Redwood Shores,Redwood City,San Mateo County,California,United States of America
# http://www.knowledgegraph.tech/iri/000196
# Redwood Shores
# http://www.knowledgegraph.tech/iri/000197
# European Committee for Interoperable Systems
# http://www.knowledgegraph.tech/iri/000199
# Oracle Corporation:,,,California,United States of America
# http://www.knowledgegraph.tech/iri/000201
# OpenAPI Initiative
# http://www.knowledgegraph.tech/iri/000202
# CVE Numbering Authorities
# http://www.knowledgegraph.tech/iri/000203
# Business Software Alliance
# http://www.knowledgegraph.tech/iri/000204
# Neda Abolhassani
# http://www.knowledgegraph.tech/iri/000205
# Accenture
# http://www.knowledgegraph.tech/iri/000206
# Accenture:,Dublin,County Dublin,Leinster,Ireland
# http://www.knowledgegraph.tech/iri/000208
# JS Foundation
# http://www.knowledgegraph.tech/iri/000213
# Accenture:,,,Irish Free State,
# http://www.knowledgegraph.tech/iri/000215
# German-Swiss Chamber of Commerce
# http://www.knowledgegraph.tech/iri/000217
# Accenture:,,,Ireland,
# http://www.knowledgegraph.tech/iri/000220
# Paul Groth
# http://www.knowledgegraph.tech/iri/000221
# University of Amsterdam
# http://www.knowledgegraph.tech/iri/000222
# Association of Universities in the Netherlands
# http://www.knowledgegraph.tech/iri/000223
# University of Amsterdam:,Amsterdam,Amsterdam,North Holland,Netherlands
# http://www.knowledgegraph.tech/iri/000224
# Stichting Academisch Erfgoed
# http://www.knowledgegraph.tech/iri/000229
# Radu Marian
# http://www.knowledgegraph.tech/iri/000234
# Bank of America
# http://www.knowledgegraph.tech/iri/000235
# Bank of America:,Charlotte,Mecklenburg County,North Carolina,United States of America
# http://www.knowledgegraph.tech/iri/000236
# Bank of America:,,,Thirteen Colonies,Kingdom of England
# http://www.knowledgegraph.tech/iri/000241
# Bank of America:,,,,Great Britain
# http://www.knowledgegraph.tech/iri/000245
# Silviu Cucerzan
# http://www.knowledgegraph.tech/iri/000247
# Microsoft Research
# http://www.knowledgegraph.tech/iri/000248
# Microsoft Research:,Redmond,King County,Washington,United States of America
# http://www.knowledgegraph.tech/iri/000250
# Yanko Ivanov
# http://www.knowledgegraph.tech/iri/000252
# Enterprise Knowledge LLC
# http://www.knowledgegraph.tech/iri/000253
# Enterprise Knowledge LLC:,,Arlington County,Virginia,United States of America
# http://www.knowledgegraph.tech/iri/000255
# Ying Ding
# http://www.knowledgegraph.tech/iri/000258
# University of Texas at Austin
# http://www.knowledgegraph.tech/iri/000259
# Innovative Multicultural Curricula for the Young European and US Engineers and Scientists
# http://www.knowledgegraph.tech/iri/000260
# University of Texas at Austin:,Austin,Travis County,Texas,United States of America
# http://www.knowledgegraph.tech/iri/000262
# Association of Research Libraries
# http://www.knowledgegraph.tech/iri/000265
# European General Data Protection Regulation
# http://www.knowledgegraph.tech/iri/000269
# California Consumer Privacy Act
# http://www.knowledgegraph.tech/iri/000272
# metadata management
# http://www.knowledgegraph.tech/iri/000277
# cyber security
# http://www.knowledgegraph.tech/iri/000279
# anti-money laundering
# http://www.knowledgegraph.tech/iri/000280
# Regulatory compliance
# http://www.knowledgegraph.tech/iri/000281
# data extraction
# http://www.knowledgegraph.tech/iri/000286
# Stock management
# http://www.knowledgegraph.tech/iri/000289
# Predictive analytics
# http://www.knowledgegraph.tech/iri/000291
# library
# http://www.knowledgegraph.tech/iri/000293
# library science
# http://www.knowledgegraph.tech/iri/000294
# Wikidata
# http://www.knowledgegraph.tech/iri/000295
# DBpedia
# http://www.knowledgegraph.tech/iri/000296
# Library of Congress Subject Headings
# http://www.knowledgegraph.tech/iri/000297
# Library of Congress Authorities
# http://www.knowledgegraph.tech/iri/000298
# authority control
# http://www.knowledgegraph.tech/iri/000299
# controlled vocabulary
# http://www.knowledgegraph.tech/iri/000300
# virtual assistant
# http://www.knowledgegraph.tech/iri/000303
# decision support system
# http://www.knowledgegraph.tech/iri/000304
# semantic network
# http://www.knowledgegraph.tech/iri/000306
# master data management
# http://www.knowledgegraph.tech/iri/000308
# EKG
# http://www.knowledgegraph.tech/iri/000309
# data modeling
# http://www.knowledgegraph.tech/iri/000310
# fake news
# http://www.knowledgegraph.tech/iri/000313
# Simple Knowledge Organization System
# http://www.knowledgegraph.tech/iri/000315
# deep learning
# http://www.knowledgegraph.tech/iri/000317
# social science
# http://www.knowledgegraph.tech/iri/000321
# VIP
# http://www.knowledgegraph.tech/iri/000322
# metadata
# http://www.knowledgegraph.tech/iri/000323
# scholarly communication
# http://www.knowledgegraph.tech/iri/000326
# Data economy
# http://www.knowledgegraph.tech/iri/000332
# data visualization
# http://www.knowledgegraph.tech/iri/000334
# engineering
# http://www.knowledgegraph.tech/iri/000335
# life sciences
# http://www.knowledgegraph.tech/iri/000336
# intelligence assessment
# http://www.knowledgegraph.tech/iri/000337
# FAIR data
# http://www.knowledgegraph.tech/iri/000339
# translational medicine
# http://www.knowledgegraph.tech/iri/000340
# deep linking
# http://www.knowledgegraph.tech/iri/000342
# binary classification
# http://www.knowledgegraph.tech/iri/000343
# GraphQL
# http://www.knowledgegraph.tech/iri/000345
# SPARQL
# http://www.knowledgegraph.tech/iri/000346
# MongoDB
# http://www.knowledgegraph.tech/iri/000347
# Elasticsearch
# http://www.knowledgegraph.tech/iri/000348
# customer relationship management
# http://www.knowledgegraph.tech/iri/000350
# graph algorithm
# http://www.knowledgegraph.tech/iri/000351
# law
# http://www.knowledgegraph.tech/iri/000353
# law firm
# http://www.knowledgegraph.tech/iri/000354
# Financial Industry Business Ontology,Stock Index
# http://www.knowledgegraph.tech/iri/000356
# derivative
# http://www.knowledgegraph.tech/iri/000357
# Global Legal Entity Identifier Foundation
# http://www.knowledgegraph.tech/iri/000358
# OpenCorporates
# http://www.knowledgegraph.tech/iri/000359
# security
# http://www.knowledgegraph.tech/iri/000360
# fraud prevention
# http://www.knowledgegraph.tech/iri/000362
# petroleum industry
# http://www.knowledgegraph.tech/iri/000364
# issue tracking system
# http://www.knowledgegraph.tech/iri/000365
# Academic
# http://www.knowledgegraph.tech/iri/000367
# Cyber security
# http://www.knowledgegraph.tech/iri/000369
# data governance
# http://www.knowledgegraph.tech/iri/000372
# drug discovery
# http://www.knowledgegraph.tech/iri/000374
# Capital One
# http://www.knowledgegraph.tech/iri/000002
# public-benefit corporation
# http://www.knowledgegraph.tech/iri/000019
# New York City
# http://www.knowledgegraph.tech/iri/000032
# New York
# http://www.knowledgegraph.tech/iri/000033
# media industry
# http://www.knowledgegraph.tech/iri/000038
# Tompkins County
# http://www.knowledgegraph.tech/iri/000048
# land-grant university
# http://www.knowledgegraph.tech/iri/000050
# sun grant institution
# http://www.knowledgegraph.tech/iri/000052
# IIIF Consortium
# http://www.knowledgegraph.tech/iri/000053
# Scholarly Publishing and Academic Resources Coalition
# http://www.knowledgegraph.tech/iri/000055
# triplestore
# http://www.knowledgegraph.tech/iri/000063
# university in France
# http://www.knowledgegraph.tech/iri/000081
# internet hosting service
# http://www.knowledgegraph.tech/iri/000093
# cloud computing
# http://www.knowledgegraph.tech/iri/000094
# computing platform
# http://www.knowledgegraph.tech/iri/000101
# application programming interface
# http://www.knowledgegraph.tech/iri/000102
# Sonoma County
# http://www.knowledgegraph.tech/iri/000107
# Ghent University
# http://www.knowledgegraph.tech/iri/000123
# East Flanders
# http://www.knowledgegraph.tech/iri/000128
# Flemish Region
# http://www.knowledgegraph.tech/iri/000129
# decentralization on the internet
# http://www.knowledgegraph.tech/iri/000130
# computer science
# http://www.knowledgegraph.tech/iri/000131
# World Wide Web
# http://www.knowledgegraph.tech/iri/000133
# Linked Data Fragments
# http://www.knowledgegraph.tech/iri/000134
# Tübingen Government Region
# http://www.knowledgegraph.tech/iri/000140
# Baden-Württemberg
# http://www.knowledgegraph.tech/iri/000141
# Germany
# http://www.knowledgegraph.tech/iri/000142
# Gesellschaft mit beschränkter Haftung
# http://www.knowledgegraph.tech/iri/000143
# Cambridgeshire
# http://www.knowledgegraph.tech/iri/000150
# East of England
# http://www.knowledgegraph.tech/iri/000151
# England
# http://www.knowledgegraph.tech/iri/000152
# Internet
# http://www.knowledgegraph.tech/iri/000155
# communication medium
# http://www.knowledgegraph.tech/iri/000157
# technology
# http://www.knowledgegraph.tech/iri/000161
# company
# http://www.knowledgegraph.tech/iri/000164
# Sofia Capital Municipality
# http://www.knowledgegraph.tech/iri/000167
# Sofia City Province
# http://www.knowledgegraph.tech/iri/000168
# Bulgaria
# http://www.knowledgegraph.tech/iri/000169
# multinational corporation
# http://www.knowledgegraph.tech/iri/000172
# FIDO Alliance
# http://www.knowledgegraph.tech/iri/000175
# investment bank
# http://www.knowledgegraph.tech/iri/000176
# asset management
# http://www.knowledgegraph.tech/iri/000177
# Hanover Township
# http://www.knowledgegraph.tech/iri/000182
# Morris County
# http://www.knowledgegraph.tech/iri/000183
# New Jersey
# http://www.knowledgegraph.tech/iri/000184
# consulting
# http://www.knowledgegraph.tech/iri/000185
# limited liability company
# http://www.knowledgegraph.tech/iri/000190
# business architecture
# http://www.knowledgegraph.tech/iri/000191
# information technology consulting
# http://www.knowledgegraph.tech/iri/000195
# Redwood City
# http://www.knowledgegraph.tech/iri/000198
# software development
# http://www.knowledgegraph.tech/iri/000200
# management consulting industry
# http://www.knowledgegraph.tech/iri/000207
# County Dublin
# http://www.knowledgegraph.tech/iri/000210
# Leinster
# http://www.knowledgegraph.tech/iri/000211
# Ireland
# http://www.knowledgegraph.tech/iri/000212
# outsourcing
# http://www.knowledgegraph.tech/iri/000214
# consulting company
# http://www.knowledgegraph.tech/iri/000218
# information technology
# http://www.knowledgegraph.tech/iri/000219
# Amsterdam
# http://www.knowledgegraph.tech/iri/000225
# North Holland
# http://www.knowledgegraph.tech/iri/000226
# Netherlands
# http://www.knowledgegraph.tech/iri/000227
# Web science
# http://www.knowledgegraph.tech/iri/000228
# altmetrics
# http://www.knowledgegraph.tech/iri/000231
# data lineage
# http://www.knowledgegraph.tech/iri/000232
# data integration
# http://www.knowledgegraph.tech/iri/000233
# Mecklenburg County
# http://www.knowledgegraph.tech/iri/000238
# North Carolina
# http://www.knowledgegraph.tech/iri/000239
# bank
# http://www.knowledgegraph.tech/iri/000240
# Kingdom of England
# http://www.knowledgegraph.tech/iri/000243
# International Standard Industrial Classification
# http://www.knowledgegraph.tech/iri/000244
# division
# http://www.knowledgegraph.tech/iri/000249
# search
# http://www.knowledgegraph.tech/iri/000256
# change management
# http://www.knowledgegraph.tech/iri/000257
# public research university
# http://www.knowledgegraph.tech/iri/000261
# Original Public Ivy
# http://www.knowledgegraph.tech/iri/000263
# public educational institution of the United States
# http://www.knowledgegraph.tech/iri/000264
# information privacy
# http://www.knowledgegraph.tech/iri/000270
# personal data
# http://www.knowledgegraph.tech/iri/000271
# data catalog
# http://www.knowledgegraph.tech/iri/000276
# reasoning
# http://www.knowledgegraph.tech/iri/000283
# supply-chain management
# http://www.knowledgegraph.tech/iri/000290
# open data
# http://www.knowledgegraph.tech/iri/000301
# fact checking
# http://www.knowledgegraph.tech/iri/000312
# graph property
# http://www.knowledgegraph.tech/iri/000319
# public data
# http://www.knowledgegraph.tech/iri/000325
# Travis County
# http://www.knowledgegraph.tech/iri/000024
# Texas
# http://www.knowledgegraph.tech/iri/000025
# Digital Library Federation
# http://www.knowledgegraph.tech/iri/000051
# Center for Research Libraries
# http://www.knowledgegraph.tech/iri/000057
# European University Association
# http://www.knowledgegraph.tech/iri/000084
# Washington
# http://www.knowledgegraph.tech/iri/000098
# real estate
# http://www.knowledgegraph.tech/iri/000120
# Belgium
# http://www.knowledgegraph.tech/iri/000122
# privacy
# http://www.knowledgegraph.tech/iri/000268
# government
# http://www.knowledgegraph.tech/iri/000324
# Web Ontology Language
# http://www.knowledgegraph.tech/iri/000328
# entity linking
# http://www.knowledgegraph.tech/iri/000330
# data management
# http://www.knowledgegraph.tech/iri/000026
# private university
# http://www.knowledgegraph.tech/iri/000045
# ORCID, Inc.
# http://www.knowledgegraph.tech/iri/000049
# research university
# http://www.knowledgegraph.tech/iri/000054
# private not-for-profit educational institution
# http://www.knowledgegraph.tech/iri/000056
# Coalition for Networked Information
# http://www.knowledgegraph.tech/iri/000058
# San Mateo County
# http://www.knowledgegraph.tech/iri/000069
# King County
# http://www.knowledgegraph.tech/iri/000097
# commercial organization
# http://www.knowledgegraph.tech/iri/000099
# subsidiary
# http://www.knowledgegraph.tech/iri/000100
# Santa Clara County
# http://www.knowledgegraph.tech/iri/000113
# open-access publisher
# http://www.knowledgegraph.tech/iri/000114
# university
# http://www.knowledgegraph.tech/iri/000125
# public company
# http://www.knowledgegraph.tech/iri/000194
# research institute
# http://www.knowledgegraph.tech/iri/000230
# taxonomy
# http://www.knowledgegraph.tech/iri/000254
# natural language processing
# http://www.knowledgegraph.tech/iri/000285
# Resource Description Framework
# http://www.knowledgegraph.tech/iri/000318
# pharmaceutical industry
# http://www.knowledgegraph.tech/iri/000147
# finance
# http://www.knowledgegraph.tech/iri/000267
# recommender system
# http://www.knowledgegraph.tech/iri/000274
# machine learning
# http://www.knowledgegraph.tech/iri/000282
# information extraction
# http://www.knowledgegraph.tech/iri/000287
# Virginia
# http://www.knowledgegraph.tech/iri/000009
# news
# http://www.knowledgegraph.tech/iri/000036
# ontology engineering
# http://www.knowledgegraph.tech/iri/000144
# professional services industry
# http://www.knowledgegraph.tech/iri/000188
# ontology
# http://www.knowledgegraph.tech/iri/000273
# Linux Foundation
# http://www.knowledgegraph.tech/iri/000003
# World Wide Web Consortium
# http://www.knowledgegraph.tech/iri/000011
# financial services
# http://www.knowledgegraph.tech/iri/000005
# credit institution
# http://www.knowledgegraph.tech/iri/000015
# graph database
# http://www.knowledgegraph.tech/iri/000041
# California
# http://www.knowledgegraph.tech/iri/000070
# enterprise
# http://www.knowledgegraph.tech/iri/000012
# Semantic Web
# http://www.knowledgegraph.tech/iri/000021
# software industry
# http://www.knowledgegraph.tech/iri/000020
# artificial intelligence
# http://www.knowledgegraph.tech/iri/000030
# business
# http://www.knowledgegraph.tech/iri/000004
# Knowledge Graph Conference 2020
# http://www.knowledgegraph.tech/iri/conference-2020
# United States of America
# http://www.knowledgegraph.tech/iri/000010
# knowledge graph
# http://www.knowledgegraph.tech/iri/000027
# Last id is  375
# Last id 2 is  375

# %%
# Remove this!
res = kgcGraph2020.query('''select distinct ?s where {?s ?p ?o. filter(regex(str(?s),"375"))}''' )
for i in res:
    print(i)

# %% [markdown]
# ## Conference Information

# %%
KGC2021 = URIRef(("http://www.knowledgegraph.tech/iri/conference-2021"))
kgcGraph2021.add((KGC2021, schema.sameAs, wd.Q106704796))

kgcGraph2021.add((KGC2021, schema.name, Literal("Knowledge Graph Conference 2021")))
kgcGraph2021.add((KGC2021, RDF.type, schema.EventSeries))
kgcGraph2021.add((KGC2021, RDF.type, kgc.Conference))
kgcGraph2021.add((KGC2021, schema.eventAttendanceMode, schema.OnlineEventAttendanceMode))
# Out:
# <Graph identifier=N56add080bc7949c980f0a82bc4dd2d5a (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Speakers

# %%
with open('KGC-2021-Speakers-Recon-1.csv', mode='r',encoding="utf-8") as csv_file:
    speaker_file = csv.DictReader(csv_file)


    for row in speaker_file:
        
        
        # Speaker's Data ---------------------------------------------------------------------------------------
        
        if row['Name']:
            name = row['Name']
            
            if name in labelDict:
                speaker = labelDict[name]
                
            else:
                newId = str(lastId).zfill(6)
                speaker = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((speaker, RDF.type, schema.Person))
                kgcGraph2021.add((speaker, schema.name, Literal(name)))
                
                if row["personQID"]:                    
                    for qid in row["personQID"].split(';'):                        
                        kgcGraph2021.add((speaker, schema.sameAs, URIRef(wd + qid.strip())))
                labelDict[name] = speaker
         
        
        
        if row["LinkedIn"]:
            linkedInProf = row["LinkedIn"]
            #print(speaker, linkedInProf,URIRef(linkedInProf))
            kgcGraph2021.add((speaker, kgc.linkedIn, URIRef(linkedInProf)))
            
            
        if row["Final Bios"]:
            kgcGraph2021.add((speaker, schema.description, Literal(row["Final Bios"])))
         
        if row["Title"]:
            kgcGraph2021.add((speaker, schema.jobTitle, Literal(row["Title"])))
         
               
        # Speaker's Country of Citizenship -------------------------------------------------------------------------- 
         
        if row["countryOfCitizenship"]:
          
            countryName = row["countryOfCitizenship"]
            if countryName in labelDict:
                country = labelDict[countryName]
            else:
                newId = str(lastId).zfill(6)
                country = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((country, RDF.type, schema.Country))
                kgcGraph2021.add((country, schema.name, Literal(countryName)))
            
                if row["countryOfCitizenshipQID"]:
                    kgcGraph2021.add((country, schema.sameAs, URIRef(wd + row["countryOfCitizenshipQID"])))
                labelDict[countryName] = country
            
            kgcGraph2021.add((speaker, schema.nationality, country)) 
            
            
        # Speaker's School Name  -------------------------------------------------------------------------- 
               
        if row["educatedAt"]:
            schoolName = row["educatedAt"]
            if schoolName in labelDict:
                school = labelDict[schoolName]
            else:
                newId = str(lastId).zfill(6)
                school = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((school, RDF.type, schema.CollegeOrUniversity))
                kgcGraph2021.add((school, schema.name, Literal(schoolName)))
                if row["educatedAtQID"]:
                    kgcGraph2021.add((school, schema.sameAs, URIRef(wd + row["educatedAtQID"])))
                labelDict[schoolName] = school
            
            kgcGraph2021.add((speaker, schema.alumniOf, school))
    
    
    
        # Person's field of Work  -------------------------------------------------------------------------- 
                
        if row["personFieldOfWork"]:
            pfowName = row["personFieldOfWork"]
            
            if pfowName in labelDict:
                pfow = labelDict[pfowName]
            else:
                newId = str(lastId).zfill(6)
                pfow = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((pfow, RDF.type, kgc.FieldOfWork))
                kgcGraph2021.add((pfow, schema.name, Literal(pfowName)))
                if row["personFieldOfWorkQID"]:                    
                    kgcGraph2021.add((pfow, schema.sameAs, URIRef(wd + row["personFieldOfWorkQID"])))
                labelDict[pfowName] = pfow
                
            kgcGraph2021.add((speaker, schema.knowsAbout, pfow))
            kgcGraph2021.add((speaker, kgc.hasFieldOfWork, pfow))

            
       
        # Person's Company   -------------------------------------------------------------------------- 
       
        if row["Company"]:
            coName = row["Company"]
            
            if coName in labelDict:
                co = labelDict[coName]
            else:
                newId = str(lastId).zfill(6)
                co = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((co, RDF.type, schema.Organization))
                kgcGraph2021.add((co, schema.name, Literal(coName)))
                if row["companyQID"]:
                    
                    for qid in row["companyQID"].split(';'):
                        kgcGraph2021.add((co, schema.sameAs, URIRef(wd + qid.strip())))
                labelDict[coName] = co
            
            kgcGraph2021.add((speaker, schema.worksFor, co))
            
            
            
        # Consortium Name   --------------------------------------------------------------------------  
        
        if row["member of"]:
            consortiumName = row["member of"]
            
            if consortiumName in labelDict:
                consortium = labelDict[consortiumName]
            else:
                newId = str(lastId).zfill(6)
                consortium = URIRef(kgcr + newId)
                lastId += 1   
                kgcGraph2021.add((consortium, RDF.type, schema.Consortium))
                kgcGraph2021.add((consortium, schema.name, Literal(consortiumName)))
                if row["memberOfQID"]:
                    kgcGraph2021.add((consortium, schema.sameAs, URIRef(wd + row["memberOfQID"])))
                labelDict[consortiumName] = consortium
            
            kgcGraph2021.add((co, schema.memberOf, consortium))
            
        
        # Additional Type Name   -------------------------------------------------------------------------------
        
        if row["instance of"]:
            instanceOfBzName = row["instance of"]
             
            if instanceOfBzName in labelDict:
                instanceOfBz = labelDict[instanceOfBzName]
            else:
                newId = str(lastId).zfill(6)
                instanceOfBz = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((instanceOfBz, RDF.type, kgc.BusinessType))
                kgcGraph2021.add((instanceOfBz, schema.name, Literal(instanceOfBzName)))
                if row["instanceOfQID"]: 
                    kgcGraph2021.add((instanceOfBz, schema.sameAs, URIRef(wd + row["instanceOfQID"])))
                labelDict[instanceOfBzName] = instanceOfBz
            
            kgcGraph2021.add((co, kgc.hasBusinessType, instanceOfBz))   
            kgcGraph2021.add((co, schema.additionalType, instanceOfBz))
        
        
        # Industry Name   -------------------------------------------------------------------------------
        
        if row["industry"]:
            industryName = row["industry"]
            
            if industryName in labelDict:
                industry = labelDict[industryName]
            else:
                newId = str(lastId).zfill(6)
                industry = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((industry, RDF.type, kgc.BusinessIndustry))
                kgcGraph2021.add((industry, schema.name, Literal(industryName)))
                
                if row["industryQID"]:
                    kgcGraph2021.add((industry, schema.sameAs, URIRef(wd + row["industryQID"])))
                labelDict[industryName] = industry
            
            kgcGraph2021.add((co, kgc.hasIndustry, industry))
            kgcGraph2021.add((co, schema.additionalType, industry))
           
 

        # Company's field of Work  -------------------------------------------------------------------------- 
        
        if row["companyFieldOfWork"]:
            cfowName = row["companyFieldOfWork"]
            
            if cfowName in labelDict:
                cfow = labelDict[cfowName]
            else:
                newId = str(lastId).zfill(6)
                cfow = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((cfow, RDF.type, kgc.FieldOfWork))
                kgcGraph2021.add((cfow, schema.name, Literal(cfowName)))
                if row["companyFieldOfWorkQID"]:
                    kgcGraph2021.add((cfow, schema.sameAs, URIRef(wd + row["companyFieldOfWorkQID"])))
                labelDict[cfowName] = cfow
            
            kgcGraph2021.add((co, schema.knowsAbout, cfow))
            kgcGraph2021.add((co, kgc.hasFieldOfWork, cfow))

        
        # Postal Address   -------------------------------------------------------------------------------   
        if (row["Address"]) or (row["City"]) or (row["County"]) or (row["State"]) or (row["Country"]):
            PAName = coName + ":" + row["Address"] + "," + row["City"] + "," +  row["County"] + ","  + row["State"] + ","  + row["Country"]
            
            
            if PAName in labelDict:
                postaladdress = labelDict[PAName]
                
            else:
                #print("Adding ", PAName)
                newId = str(lastId).zfill(6)
                postaladdress = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((postaladdress, RDF.type, schema.PostalAddress))
                kgcGraph2021.add((postaladdress, schema.name, Literal(PAName)))
                kgcGraph2021.add((co, schema.address, postaladdress))
                #if row["PostalAddressQID"]:
                #    kgcGraph2021.add((postaladdress, schema.sameAs, URIRef(wd + row["PostalAddressQID"])))
                labelDict[PAName] = postaladdress
            
        # Stree Address   -------------------------------------------------------------------------------   
                
        if row["Address"]:
            AddressName = row["Address"]
            
            if AddressName in labelDict:
                Address = labelDict[AddressName]
            else:
                newId = str(lastId).zfill(6)
                Address = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((Address, schema.name, Literal(AddressName)))
                kgcGraph2021.add((Address, RDF.type, kgc.Address))
                if row["AddressQID"]:
                    kgcGraph2021.add((Address, schema.sameAs, URIRef(wd + row["AddressQID"])))
                labelDict[AddressName] = Address
                
            kgcGraph2021.add((postaladdress, kgc.streetAddress, Address))
            
            
                  
            
        # City    -------------------------------------------------------------------------------   
                        
        if row["City"]:
            CityName = row["City"]
            
            if CityName in labelDict:
                City = labelDict[CityName]
            else:
                newId = str(lastId).zfill(6)
                City = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((City, schema.name, Literal(CityName)))
                kgcGraph2021.add((City, RDF.type, schema.City))
                if row["CityQID"]:
                    kgcGraph2021.add((City, schema.sameAs, URIRef(wd + row["CityQID"])))
                labelDict[CityName] = City
            
            if row["Address"]:
                kgcGraph2021.add((postaladdress, kgc.addressCity, City))
                kgcGraph2021.add((Address, schema.geoWithin, City))
            
            
        # County   -------------------------------------------------------------------------------   
               
        if row["County"]:
            CountyName = row["County"]
            
            if CountyName in labelDict:
                County = labelDict[CountyName]
            else:
                newId = str(lastId).zfill(6)
                County = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((County, schema.name, Literal(CountyName)))
                kgcGraph2021.add((County, RDF.type, kgc.County))
                if row["CountyQID"]:
                    kgcGraph2021.add((County, schema.sameAs, URIRef(wd + row["CountyQID"])))
                labelDict[CountyName] = County
            
            if row["City"]:
                kgcGraph2021.add((postaladdress, kgc.addressCounty, County))
                kgcGraph2021.add((City, schema.geoWithin, County))
            
        
        # State   -------------------------------------------------------------------------------   
              
        if row["State"]:
            StateName = row["State"]
            
            if StateName in labelDict:
                State = labelDict[StateName]
            else:
                newId = str(lastId).zfill(6)
                State = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((State, schema.name, Literal(StateName)))
                kgcGraph2021.add((State, RDF.type, schema.State))
                if row["StateQID"]:
                    kgcGraph2021.add((State, schema.sameAs, URIRef(wd + row["StateQID"])))
                labelDict[StateName] = State
            
            if row["County"]:
                kgcGraph2021.add((postaladdress, kgc.addressRegion, State))
                kgcGraph2021.add((County, schema.geoWithin, State))
                
            
        
        # Country   ------------------------------------------------------------------------------- 
                
        if row["Country"]:
            CountryName = row["Country"]
            
            if CountryName in labelDict:
                Country = labelDict[CountryName]
            else:
                newId = str(lastId).zfill(6)
                Country = URIRef(kgcr + newId)
                lastId += 1 
                kgcGraph2021.add((Country, schema.name, Literal(CountryName)))
                kgcGraph2021.add((Country, RDF.type, schema.Country))
                if row["CountryQID"]:
                    kgcGraph2021.add((Country, schema.sameAs, URIRef(wd + row["CountryQID"])))
                labelDict[CountryName] = Country
            
            if row["State"]:
                kgcGraph2021.add((postaladdress, schema.addressCountry, Country))
                kgcGraph2021.add((State, schema.geoWithin, Country))

# %% [markdown]
# ## Presentations

# %%
#tagsDict={}

# %%
with open('KGC-2021-Presentations-Recon-1.csv', mode='r', encoding="utf-8") as csv_file:
    presentation_file = csv.DictReader(csv_file)

    for row in presentation_file:
        
        
        # Title + Description Presentation ------------------------------------------------------------------------------------
        
        
        if row['Title']:
            title = row['Title']            
            
            if title in labelDict:
                talk = labelDict[title]
            else:
                newId = str(lastId).zfill(6)
                talk = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((talk, RDF.type, kgc.Talk))
                kgcGraph2021.add((talk, schema.name, Literal(title)))
                labelDict[title] = talk    
            kgcGraph2021.add((talk, schema.superEvent, KGC2021))
            
        if row["Description"]:
            kgcGraph2021.add((talk, schema.abstract, Literal(row["Description"])))
                
        
        
        # Presenter of Presentation --------------------------------------------------------------------------------
        
        
        if row['Name']:
            presenterName = row['Name']
            
            
            if presenterName in labelDict:
                presenter = labelDict[presenterName]
                                
            else:
                print("Error: Presenter {} not in the list of speakers! Please add his full details to the Speakers File.".format(presenterName))
                newId = str(lastId).zfill(6)
                presenter = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((presenter, RDF.type, schema.Person))
                kgcGraph2021.add((presenter, schema.name, Literal(presenterName)))
                labelDict[title] = talk    
            kgcGraph2021.add((talk, schema.performer, presenter))
            
        
        # Tags of Presentation ------------------------------------------------------------------------------------
        
        if row["Tag"]:
            tagName = row["Tag"]
            
            if tagName in labelDict:
                tag = labelDict[tagName]
            else:
                newId = str(lastId).zfill(6)
                tag = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((tag, RDF.type, kgc.Tag))
                kgcGraph2021.add((tag, schema.name, Literal(tagName))) 
                if row["TagQID"]:
                    
                    kgcGraph2021.add((tag, schema.sameAs, URIRef(wd + row["TagQID"])))
                labelDict[tagName] = tag
            
            kgcGraph2021.add((talk, schema.about, tag)) 
        
        
        
        # Facet Of
        
        if row["FacetOf"]:
            facetName = row["FacetOf"]
            
            
            if facetName in labelDict:
                facet = labelDict[facetName]
            else:
                newId = str(lastId).zfill(6)
                facet = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((facet, RDF.type, kgc.Tag))
                kgcGraph2021.add((facet, schema.name, Literal(facetName))) 
                if row["FacetOfQID"]:
                    kgcGraph2021.add((facet, schema.sameAs, URIRef(wd + row["FacetOfQID"])))
                labelDict[facetName] = facet
            kgcGraph2021.add((tag, kgc.facetOf, facet)) 
        
        
        # Video URL of Presentation ------------------------------------------------------------------------------------
        
        
        if row["Video URL"]:
            videoURL = row["Video URL"]
            
            if videoURL in labelDict:
                video = labelDict[videoURL]
            else:
                newId = str(lastId).zfill(6)
                video = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((talk, schema.recordedIn, video))
                kgcGraph2021.add((video, RDF.type, schema.VideoObject))
                kgcGraph2021.add((video, schema.embedUrl, Literal(videoURL))) 
                #kgcGraph2021.add((video, schema.name, Literal(videoURL))) 
                labelDict[videoURL] = video
            kgcGraph2021.add((talk, schema.workPerformed, video))    
                
                  
        # Slides URL of Presentation ------------------------------------------------------------------------------------
        
        
        if row["Slides URL"]:
            slidesURL = row["Slides URL"]
            
            if slidesURL in labelDict:
                slides = labelDict[slidesURL]
            else:
                newId = str(lastId).zfill(6)
                slides = URIRef(kgcr + newId)
                lastId += 1
                kgcGraph2021.add((slides, schema.about, talk))
                kgcGraph2021.add((slides, RDF.type, schema.PresentationDigitalDocument))
                kgcGraph2021.add((slides, schema.archivedAt, Literal(slidesURL)))
                #kgcGraph2021.add((slides, schema.name, Literal(slidesURL))) 
                labelDict[slidesURL] = slides  
                
            kgcGraph2021.add((talk, schema.workPerformed, slides))

# %% [markdown]
# ## Serialize

# %%
kgcGraph2021.serialize(destination = "kgc2021-1.ttl", format = "turtle")
# Out:
# <Graph identifier=N56add080bc7949c980f0a82bc4dd2d5a (<class 'rdflib.graph.Graph'>)>
